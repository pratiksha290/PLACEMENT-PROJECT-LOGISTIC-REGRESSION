# %%
import pandas as pd

# %%
df = pd.read_csv('/content/placement.csv')

# %%
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df=df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %% [markdown]
# EDA

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %% [markdown]
# EXTRACT INPUT AND OUTPUT COLS

# %%
x=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y.shape
# Out:
# (100,)

# %% [markdown]
# train test split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 63   6.3  128.0
# 5    7.1   48.0
# 61   7.3  137.0
# 15   5.1  176.0
# 94   4.7   52.0
# ..   ...    ...
# 26   7.0  199.0
# 36   5.7  140.0
# 64   7.0   64.0
# 65   8.1  166.0
# 55   7.8  114.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 63    1
# 5     1
# 61    1
# 15    0
# 94    0
#      ..
# 26    1
# 36    0
# 64    1
# 65    1
# 55    1
# Name: placement, Length: 90, dtype: int64

# %%
x_test
# Out:
#     cgpa     iq
# 99   6.2  113.0
# 21   7.1  151.0
# 86   5.1  128.0
# 24   4.7  121.0
# 29   7.0  112.0
# 10   6.0   45.0
# 62   6.0  102.0
# 89   4.9  151.0
# 59   4.8  112.0
# 25   5.0   91.0

# %%
y_test
# Out:
# 99    1
# 21    1
# 86    0
# 24    0
# 29    1
# 10    1
# 62    0
# 89    0
# 59    0
# 25    0
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[ 0.23666116,  0.07885495],
#        [ 0.92652365, -1.89251881],
#        [ 1.09898927,  0.3006345 ],
#        [-0.79813258,  1.26167921],
#        [-1.14306382, -1.79395012],
#        [-0.71189976,  0.17742364],
#        [-0.71189976, -0.36470415],
#        [ 1.35768771,  0.07885495],
#        [ 0.75405803,  0.34991884],
#        [-0.9705982 ,  0.74419359],
#        [ 1.09898927, -1.84323447],
#        [-0.71189976,  0.89204663],
#        [-0.9705982 ,  0.22670798],
#        [-0.9705982 , -0.11828243],
#        [ 0.40912678, -2.1635827 ],
#        [ 0.06419554,  0.17742364],
#        [-0.1945029 ,  1.01525749],
#        [ 0.23666116, -0.53719935],
#        [-1.22929663,  0.52241405],
#        [ 1.70261895, -1.12861148],
#        [-0.02203727, -0.01971374],
#        [ 0.58159241,  0.71955142],
#        [-2.35032318,  1.43417441],
#        [ 1.2714549 ,  0.81812011],
#        [ 0.32289397, -0.21685111],
#        [ 0.49535959,  0.32527667],
#        [ 0.40912678,  0.12813929],
#        [-0.02203727,  0.59634056],
#        [-1.7466935 , -0.61112587],
#        [-1.05683101,  0.94133097],
#        [ 0.40912678, -0.85754759],
#        [ 1.09898927, -0.95611627],
#        [ 0.66782522, -0.04435591],
#        [-1.40176226,  0.59634056],
#        [ 0.84029084,  0.34991884],
#        [-1.7466935 , -1.22718017],
#        [ 2.13378301, -0.11828243],
#        [-1.14306382, -0.9314741 ],
#        [ 0.66782522,  0.39920319],
#        [ 0.75405803,  0.32527667],
#        [-0.9705982 ,  1.75452265],
#        [ 0.40912678,  0.86740445],
#        [ 0.66782522, -0.85754759],
#        [-0.28073571,  1.089184  ],
#        [-0.02203727, -1.44895971],
#        [ 0.32289397,  0.39920319],
#        [-0.88436539, -1.52288623],
#        [ 1.18522209,  0.17742364],
#        [-0.62566695, -0.26613546],
#        [-0.79813258, -1.44895971],
#        [ 1.09898927, -0.21685111],
#        [-0.53943414,  0.34991884],
#        [ 0.49535959, -0.11828243],
#        [-0.10827009, -0.46327283],
#        [ 0.23666116,  0.05421278],
#        [-1.83292631, -0.38934632],
#        [ 0.06419554, -1.07932713],
#        [-0.71189976,  2.44450346],
#        [ 0.66782522, -0.3154198 ],
#        [ 0.58159241,  1.40953224],
#        [-1.40176226, -2.04037184],
#        [ 1.35768771, -0.88218976],
#        [ 1.78885176,  0.59634056],
#        [-0.62566695, -0.09364025],
#        [-1.05683101,  1.089184  ],
#        [-0.9705982 , -1.57217057],
#        [ 0.84029084,  1.23703704],
#        [-0.28073571,  0.44848753],
#        [-0.71189976, -0.85754759],
#        [-1.48799507,  1.85309134],
#        [ 0.06419554, -1.47360189],
#        [-0.1945029 ,  0.42384536],
#        [ 0.06419554,  0.76883577],
#        [-0.53943414, -0.26613546],
#        [ 1.96131739,  1.06454183],
#        [ 1.2714549 ,  0.12813929],
#        [-2.17785756,  2.66628301],
#        [ 0.06419554, -0.53719935],
#        [-0.53943414,  0.25135015],
#        [ 1.2714549 , -1.57217057],
#        [-0.28073571,  0.17742364],
#        [-0.53943414, -0.43863066],
#        [-1.05683101,  0.39920319],
#        [-0.88436539, -0.16756677],
#        [ 0.75405803, -0.70969455],
#        [ 0.84029084,  1.82844916],
#        [-0.28073571,  0.37456101],
#        [ 0.84029084, -1.49824406],
#        [ 1.78885176,  1.01525749],
#        [ 1.53015333, -0.26613546]])

# %%
x_test=scaler.transform(x_test)

# %%
x_test
# Out:
# array([[ 0.15042835, -0.29077763],
#        [ 0.92652365,  0.64562491],
#        [-0.79813258,  0.07885495],
#        [-1.14306382, -0.09364025],
#        [ 0.84029084, -0.3154198 ],
#        [-0.02203727, -1.96644533],
#        [-0.02203727, -0.56184152],
#        [-0.9705982 ,  0.64562491],
#        [-1.05683101, -0.3154198 ],
#        [-0.88436539, -0.83290541]])

# %%
from sklearn.linear_model import LogisticRegression
clf=LogisticRegression()

# %%
#model training
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred= clf.predict(x_test)

# %%
y_test
# Out:
# 99    1
# 21    1
# 86    0
# 24    0
# 29    1
# 10    1
# 62    0
# 89    0
# 59    0
# 25    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train,y_train.values,clf=clf,legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pk1','wb'))
